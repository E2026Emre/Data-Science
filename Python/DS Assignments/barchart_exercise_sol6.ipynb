# %%
import numpy as np
import pandas as pd
from collections import Counter
from matplotlib import pyplot as plt

# %% [markdown]
# df = pd.read_csv('bar_data.csv', sep=',')
# new_df = pd.DataFrame(df.LanguagesWorkedWith.str.split(';').tolist(), index=df.Responder_id).stack()
# new_df = new_df.reset_index([0, 'Responder_id'])
# new_df.columns = ['Responder_id', 'languages']
# new_df.head()
# new_df.shape
# new_df.sort_values(by=['Responder_id'], ascending=True)
# lang_summ = new_df["languages"].value_counts(dropna = False)
# lang_summ.head()
# lang_summ.plot(figsize=(10,7), kind = 'barh')

# %%
df = pd.read_csv("bar_data.csv")

# %%
df.LanguagesWorkedWith
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 87564                             HTML/CSS;Java;JavaScript
# 87565                           HTML/CSS;JavaScript;Python
# 87566    Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 87567                        HTML/CSS;JavaScript;Other(s):
# 87568    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguagesWorkedWith, Length: 87569, dtype: object

# %%
df.LanguagesWorkedWith.str.split(';')
# Out:
# 0                     [HTML/CSS, Java, JavaScript, Python]
# 1                                  [C++, HTML/CSS, Python]
# 2                                               [HTML/CSS]
# 3                                [C, C++, C#, Python, SQL]
# 4        [C++, HTML/CSS, Java, JavaScript, Python, SQL,...
#                                ...
# 87564                         [HTML/CSS, Java, JavaScript]
# 87565                       [HTML/CSS, JavaScript, Python]
# 87566    [Bash/Shell/PowerShell, Go, HTML/CSS, JavaScri...
# 87567                    [HTML/CSS, JavaScript, Other(s):]
# 87568    [Bash/Shell/PowerShell, HTML/CSS, Java, JavaSc...
# Name: LanguagesWorkedWith, Length: 87569, dtype: object

# %%
df.LanguagesWorkedWith.str.split(';').tolist()
# Out:
# [['HTML/CSS', 'Java', 'JavaScript', 'Python'],
#  ['C++', 'HTML/CSS', 'Python'],
#  ['HTML/CSS'],
#  ['C', 'C++', 'C#', 'Python', 'SQL'],
#  ['C++', 'HTML/CSS', 'Java', 'JavaScript', 'Python', 'SQL', 'VBA'],
#  ['Java', 'R', 'SQL'],
#  ['HTML/CSS', 'JavaScript'],
#  ['Bash/Shell/PowerShell',
#   'C',
#   'C++',
#   'HTML/CSS',
#   'Java',
#   'JavaScript',
#   'Python',
#   'SQL'],
#  ['Bash/Shell/PowerShell',
#   'C#',
#   'HTML/CSS',
#   'JavaScript',
#   'Python',
#   'Ruby',
#   'Rust',
#   'SQL',
#   'TypeScript',
#   'WebAssembly',
#   'Other(s):'],
#  ['C#', 'Go', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Other(s):'],
#  ['Bash/Shell/PowerShell', 'HTML/CSS', 'Java', 'Python', 'R', 'SQL'],
#  ['Bash/Shell/PowerShell',
#   'HTML/CSS',
#   'JavaScript',
#   'PHP',
#   'SQL',
#   'TypeScript'],
#  ['C++'],
#  ['Assembly',
#   'Bash/Shell/PowerShell',
#   'C',
#   'C++',
#   'HTML/CSS',
#   'Java',
#   'JavaScript',
#   'PHP',
#   'SQL'],
#  ['Bash/Shell/PowerShell',
#   'C#',
# ...

# %%
new_df = pd.DataFrame(df.LanguagesWorkedWith.str.split(';').tolist())
new_df
# Out:
#                           0           1           2           3            4   \
# 0                   HTML/CSS        Java  JavaScript      Python         None
# 1                        C++    HTML/CSS      Python        None         None
# 2                   HTML/CSS        None        None        None         None
# 3                          C         C++          C#      Python          SQL
# 4                        C++    HTML/CSS        Java  JavaScript       Python
# ...                      ...         ...         ...         ...          ...
# 87564               HTML/CSS        Java  JavaScript        None         None
# 87565               HTML/CSS  JavaScript      Python        None         None
# 87566  Bash/Shell/PowerShell          Go    HTML/CSS  JavaScript  WebAssembly
# 87567               HTML/CSS  JavaScript   Other(s):        None         None
# 87568  Bash/Shell/PowerShell    HTML/CSS        Java  JavaScript          PHP
#
# ...

# %%
new_df = pd.DataFrame(df.LanguagesWorkedWith.str.split(';').tolist(), index=df.Responder_id)
new_df
# Out:
#                                  0           1           2           3   \
# Responder_id
# 1                          HTML/CSS        Java  JavaScript      Python
# 2                               C++    HTML/CSS      Python        None
# 3                          HTML/CSS        None        None        None
# 4                                 C         C++          C#      Python
# 5                               C++    HTML/CSS        Java  JavaScript
# ...                             ...         ...         ...         ...
# 88182                      HTML/CSS        Java  JavaScript        None
# 88212                      HTML/CSS  JavaScript      Python        None
# 88282         Bash/Shell/PowerShell          Go    HTML/CSS  JavaScript
# 88377                      HTML/CSS  JavaScript   Other(s):        None
# 88863         Bash/Shell/PowerShell    HTML/CSS        Java  JavaScript
#
#                        4     5      6     7     8     9   ...    18    19  \
# ...

# %%
new_df = pd.DataFrame(df.LanguagesWorkedWith.str.split(';').tolist(), index=df.Responder_id).stack()
new_df
# Out:
# Responder_id
# 1             0      HTML/CSS
#               1          Java
#               2    JavaScript
#               3        Python
# 2             0           C++
#                       ...
# 88863         2          Java
#               3    JavaScript
#               4           PHP
#               5           SQL
#               6         Swift
# Length: 440505, dtype: object

# %%
new_df = new_df.reset_index([0, 'Responder_id'])
new_df
# Out:
#         Responder_id           0
# 0                  1    HTML/CSS
# 1                  1        Java
# 2                  1  JavaScript
# 3                  1      Python
# 4                  2         C++
# ...              ...         ...
# 440500         88863        Java
# 440501         88863  JavaScript
# 440502         88863         PHP
# 440503         88863         SQL
# 440504         88863       Swift
#
# [440505 rows x 2 columns]

# %%
new_df.columns = ['Responder_id', 'languages']
new_df
# Out:
#         Responder_id   languages
# 0                  1    HTML/CSS
# 1                  1        Java
# 2                  1  JavaScript
# 3                  1      Python
# 4                  2         C++
# ...              ...         ...
# 440500         88863        Java
# 440501         88863  JavaScript
# 440502         88863         PHP
# 440503         88863         SQL
# 440504         88863       Swift
#
# [440505 rows x 2 columns]

# %%
new_df.groupby("languages").count().sort_values(by = "languages")
# Out:
#                        Responder_id
# languages
# Assembly                       5833
# Bash/Shell/PowerShell         31991
# C                             18017
# C#                            27097
# C++                           20524
# Clojure                        1254
# Dart                           1683
# Elixir                         1260
# Erlang                          777
# F#                              973
# Go                             7201
# HTML/CSS                      55466
# Java                          35917
# JavaScript                    59219
# Kotlin                         5620
# Objective-C                    4191
# Other(s):                      7920
# PHP                           23030
# Python                        36443
# R                              5048
# Ruby                           7331
# Rust                           2794
# SQL                           47544
# Scala                          3309
# Swift                          5744
# ...

# %%
fin_df = new_df.groupby("languages").count().sort_values(by = "Responder_id", ascending = False).head(15)

# %%
fin_df
# Out:
#                        Responder_id
# languages
# JavaScript                    59219
# HTML/CSS                      55466
# SQL                           47544
# Python                        36443
# Java                          35917
# Bash/Shell/PowerShell         31991
# C#                            27097
# PHP                           23030
# C++                           20524
# TypeScript                    18523
# C                             18017
# Other(s):                      7920
# Ruby                           7331
# Go                             7201
# Assembly                       5833

# %%
fin_df.plot.barh(figsize = (10, 8))
plt.show()
