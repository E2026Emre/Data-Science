# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df1=pd.read_csv("df1", index_col=0)
df2=pd.read_csv("df2")

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
sns.set_style("darkgrid")

# %%
df1["A"].hist();

# %% [markdown]
# ## areaplot

# %%
df = pd.DataFrame({'sales': [3, 2, 3, 9, 10, 6], 'signups': [5, 5, 6, 12, 14, 13],
                   'visits': [20, 42, 28, 62, 81, 50]},
                  index=pd.date_range(start='2018/01/01', end='2018/07/01',
                                      freq='M'))
df.head()
# Out:
#             sales  signups  visits
# 2018-01-31      3        5      20
# 2018-02-28      2        5      42
# 2018-03-31      3        6      28
# 2018-04-30      9       12      62
# 2018-05-31     10       14      81

# %%
df.shape
# Out:
# (6, 3)

# %%
df.plot.area(figsize=(9,6));

# %%
df.plot(kind="area", figsize=(9,6));

# %% [markdown]
# ## barplot

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant','rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,'lifespan': lifespan}, index=index)
df.head()
# Out:
#           speed  lifespan
# snail       0.1       2.0
# pig        17.5       8.0
# elephant   40.0      70.0
# rabbit     48.0       1.5
# giraffe    52.0      25.0

# %%
df.plot.bar(figsize=(9,6));

# %%
df.plot(kind="bar", figsize=(9,6), rot=45)
plt.axhline(y=50, color="green", ls="--");

# %%
g = df.plot(kind="bar", figsize=(9,6), rot=45)
for p in g.patches:
    g.annotate((p.get_height()), (p.get_x()+0.02, p.get_height()+0.5))
plt.axhline(y=50, color="green", ls="--");

# %%
labels=['Snail', 'Pig', 'Elephant','Rabbit', 'Giraffe', 'Coyote', 'Horse']

# %%
g = df.plot(kind="bar", figsize=(9,6), rot=45)
g.set_xticklabels(labels)
g.set_ylabel("speed/lifespan")
for p in g.patches:
    g.annotate((p.get_height()), (p.get_x()+0.02, p.get_height()+0.5))
plt.axhline(y=50, color="green", ls="--");

# %%
income = [100, 80, 150, 48, 52, 69, 88]
expense = [30, 100, 100, 20, 75, 50, 28]
index = ['snail', 'pig', 'elephant','rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'income': income,'expense': expense}, index=index)
df.head()
# Out:
#           income  expense
# snail        100       30
# pig           80      100
# elephant     150      100
# rabbit        48       20
# giraffe       52       75

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(stacked=True);

# %%
df["profit/lost"] = df["income"] - df["expense"]

# %%
df
# Out:
#           income  expense  profit/lost
# snail        100       30           70
# pig           80      100          -20
# elephant     150      100           50
# rabbit        48       20           28
# giraffe       52       75          -23
# coyote        69       50           19
# horse         88       28           60

# %%
df.plot.bar(figsize=(8,4));

# %%
df.loc["Total"] = df.sum()

# %%
df
# Out:
#           income  expense  profit/lost
# snail        100       30           70
# pig           80      100          -20
# elephant     150      100           50
# rabbit        48       20           28
# giraffe       52       75          -23
# coyote        69       50           19
# horse         88       28           60
# Total        587      403          184

# %% [markdown]
# ## histograms

# %%
mpg=sns.load_dataset("mpg")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.horsepower.plot.hist(bins=20);

# %% [markdown]
# ## lineplots

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1["B"].plot(); # default değeri "line"
# Out:
# C:\Users\acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
df1["B"].plot.line();
# Out:
# C:\Users\acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
df1.plot(y="B"); # index' otomatik olarak x eksenine atar, ayrıca tanımlarsak hata verir.
# Out:
# C:\Users\acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
df1.B.head()
# Out:
# 2000-01-01   -0.163643
# 2000-01-02    0.137034
# 2000-01-03   -0.482943
# 2000-01-04   -0.072973
# 2000-01-05    1.778576
# Name: B, dtype: float64

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.groupby("model_year").horsepower.mean().plot();

# %%
mpg.groupby("model_year").mpg.mean().plot(ls="--");

# %%
from pandas_datareader import data
from datetime import datetime
start = datetime(2020, 1, 1)
end = datetime(2020, 8, 30)

# %%
f = data.DataReader(name="AAPL", data_source="av-daily", start=start, end=end, api_key = "CI1UUA44YI12JAB3")
# https://www.alphavantage.co/support/#api-key  => to create the API key

# %%
f.head()
# Out:
#               open    high     low   close    volume
# 2020-01-02  296.24  300.60  295.19  300.35  33870100
# 2020-01-03  297.15  300.58  296.50  297.43  36580700
# 2020-01-06  293.79  299.96  292.75  299.80  29596800
# 2020-01-07  299.84  300.90  297.48  298.39  27218000
# 2020-01-08  297.16  304.44  297.16  303.19  33019800

# %%
f.tail()
# Out:
#                 open      high      low   close    volume
# 2020-08-24  514.7900  515.1400  495.745  503.43  86484442
# 2020-08-25  498.7900  500.7172  492.210  499.30  52873947
# 2020-08-26  504.7165  507.9700  500.330  506.09  40755567
# 2020-08-27  508.5700  509.9400  495.330  500.04  38888096
# 2020-08-28  504.0500  505.7700  498.310  499.23  46907479

# %%
f.close.plot(figsize=(10,7));
# Out:
# C:\Users\acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
f.index=pd.to_datetime(f.index)

# %%
f.close.plot(figsize=(10,7));

# %%
import matplotlib.dates as mdates
import numpy as np
fig, ax = plt.subplots(figsize=(10,7))
#ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.set_xticklabels(f.index, rotation=45)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=15))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.plot(f.close.index, f.close);
# Out:
# <ipython-input-43-c74729c3148a>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(f.index, rotation=45)

# %% [markdown]
# ## moving avgs

# %%
seven = f.close.rolling(window = 7).mean()

# %%
seven.head(10)
# Out:
# 2020-01-02           NaN
# 2020-01-03           NaN
# 2020-01-06           NaN
# 2020-01-07           NaN
# 2020-01-08           NaN
# 2020-01-09           NaN
# 2020-01-10    302.731429
# 2020-01-13    305.104286
# 2020-01-14    307.282857
# 2020-01-15    308.931429
# Name: close, dtype: float64

# %%
ten = f.close.rolling(window = 10).mean()

# %%
ten.head(12)
# Out:
# 2020-01-02        NaN
# 2020-01-03        NaN
# 2020-01-06        NaN
# 2020-01-07        NaN
# 2020-01-08        NaN
# 2020-01-09        NaN
# 2020-01-10        NaN
# 2020-01-13        NaN
# 2020-01-14        NaN
# 2020-01-15    306.010
# 2020-01-16    307.499
# 2020-01-17    309.629
# Name: close, dtype: float64

# %%
twenty = f.close.rolling(window = 20).mean()

# %%
thirty = f.close.rolling(window = 30).mean()

# %%
plt.figure(figsize=(15,10))
f.close.plot(ls="-")
seven.plot(ls="--")
ten.plot(ls="-.")
twenty.plot(ls=":")
thirty.plot()
plt.legend(["close", "seven", "ten", "twenty", "thirty"]);

# %%
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes 
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
fig=plt.figure(figsize=(14,5))
f.close.plot()
seven.plot(ls='--')
ten.plot(ls='-.')
twenty.plot(ls=':')
thirty.plot()
plt.legend(['close', 'seven', 'ten', 'twenty', 'thirty'])
ax = plt.axes()
ax.plot(f.close)
x1 = f.close.index[100]
x2 = f.close.index[120]
y1 = 300
y2 = 370
# Make the zoom-in plot:
axins = zoomed_inset_axes(ax, 2, loc=1) # zoom = 2
axins.plot(f)
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="0.5")
plt.show()
# Out:
# <ipython-input-66-2c380eb06069>:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()

# %% [markdown]
# ## scatter plots

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.plot.scatter(x="mpg", y="weight");

# %%
mpg.plot.scatter(x="mpg", y="weight", c="horsepower", cmap="coolwarm");

# %% [markdown]
# ## Hexagonal Bin Plot

# %%
mpg.plot.hexbin("mpg", "weight", gridsize=20);

# %% [markdown]
# ## Box Plot

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.weight.plot.box();

# %%
mpg.horsepower.plot.box();

# %%
sns.boxplot(x="origin",y="horsepower",data=mpg);

# %%
mpg.plot.box();

# %%
mpg.boxplot(column="horsepower", by="origin");

# %%
df = mpg = sns.load_dataset("mpg")
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
sns.boxplot(df["horsepower"], ax=ax_box)
sns.distplot(df["horsepower"], ax=ax_hist)
ax_box.set(xlabel="")
# Out:
# [Text(0.5, 0, '')]

# %% [markdown]
# ## kde plot

# %%
mpg.horsepower.plot.kde();

# %%
mpg.horsepower.plot.density();
