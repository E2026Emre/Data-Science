# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cleaned_autos.csv")

# %%
pd.set_option('display.max_columns', None)
df.head(3)
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat     Offer
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat     Offer
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat     Offer
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test       Other                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190  Other
# 2   9800   test         suv                2004  automatik      163  grand
#
#    kilometer monthOfRegistration  fuelType       brand notRepairedDamage  \
# 0     150000                 Jan  Gasoline  volkswagen             Other
# 1     125000                 May    Diesel        audi               Yes
# 2     125000                 Aug    Diesel        jeep             Other
#
#            dateCreated  postalCode             lastSeen  yearOfCreation  \
# 0  2016-03-24 00:00:00       70435  2016-04-07 03:16:57            2016
# 1  2016-03-24 00:00:00       66954  2016-04-07 01:46:50            2016
# 2  2016-03-14 00:00:00       90480  2016-04-05 12:47:46            2016
#
#    yearCrawled monthOfCreation monthCrawled  NoOfDaysOnline  NoOfHrsOnline  \
# 0         2016           March        March              14              3
# 1         2016           March        March              14              1
# 2         2016           March        March              22             12
#
#    yearsOld  monthsOld
# 0        23         11
# 1         5          7
# 2        12          4

# %%
df.shape
# Out:
# (313687, 27)

# %%
df.vehicleType.unique()
# Out:
# array(['Other', 'coupe', 'suv', 'kleinwagen', 'limousine', 'cabrio',
#        'kombi', 'bus', 'andere'], dtype=object)

# %% [markdown]
# ## Variation of the price range by the vehicle type

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.boxplot(x="vehicleType", y="price", data=df)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.violinplot(x="vehicleType", y="price", data=df)
plt.show()

# %% [markdown]
# ## Demonstration of the mean pricec by the vehicle type

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.pointplot(x="vehicleType", y="price", data=df)
ax.set_xticklabels(df.vehicleType.unique(), rotation=90);

# %%
df.groupby("vehicleType").price.mean().sort_values()
# Out:
# vehicleType
# Other           861.466447
# kleinwagen     1730.123085
# andere         2400.906465
# limousine      3745.179122
# kombi          3961.032129
# bus            4677.360601
# coupe          6741.053960
# cabrio         6934.699382
# suv           10772.809349
# Name: price, dtype: float64

# %%
df.groupby("vehicleType").price.mean().sort_values().index
# Out:
# Index(['Other', 'kleinwagen', 'andere', 'limousine', 'kombi', 'bus', 'coupe',
#        'cabrio', 'suv'],
#       dtype='object', name='vehicleType')

# %%
df.groupby("vehicleType").price.mean().sort_values().values
# Out:
# array([  861.46644727,  1730.12308535,  2400.90646492,  3745.17912152,
#         3961.03212891,  4677.36060075,  6741.05395981,  6934.69938199,
#        10772.80934855])

# %%
order = df.groupby("vehicleType").price.mean().sort_values().index

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.pointplot(x="vehicleType", y="price", order = order, data=df)
# Out:
# <AxesSubplot:xlabel='vehicleType', ylabel='price'>

# %%
df.groupby("vehicleType").price.mean().sort_values().plot(marker ="o", figsize = (10,4))
# Out:
# C:\Users\acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='vehicleType'>

# %% [markdown]
# ## Total count of vehicles by type available on ebay for sale

# %%
fig, ax = plt.subplots(figsize=(15, 7))
sns.countplot(df.vehicleType)
# Out:
# <AxesSubplot:xlabel='vehicleType', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(15, 7))
sns.countplot(df.vehicleType, order=df.vehicleType.value_counts().index)b
# Out:
# <AxesSubplot:xlabel='vehicleType', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(15, 7))
g = sns.countplot(df.vehicleType, order=df.vehicleType.value_counts().index)

for p in g.patches:
    g.annotate((p.get_height()), (p.get_x()+0.2, p.get_height()+1000))

# %%
#pandas
df.vehicleType.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
x = df.vehicleType.value_counts()

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax.bar(x.index, x.values);

# %% [markdown]
# ### No of Vehicles by Brand Available on ebay for sale

# %%
df.head(1)
# Out:
#            dateCrawled        name  seller offerType  price abtest  \
# 0  2016-03-24 11:52:17  Golf_3_1.6  privat     Offer    480   test
#
#   vehicleType  yearOfRegistration  gearbox  powerPS model  kilometer  \
# 0       Other                1993  manuell        0  golf     150000
#
#   monthOfRegistration  fuelType       brand notRepairedDamage  \
# 0                 Jan  Gasoline  volkswagen             Other
#
#            dateCreated  postalCode             lastSeen  yearOfCreation  \
# 0  2016-03-24 00:00:00       70435  2016-04-07 03:16:57            2016
#
#    yearCrawled monthOfCreation monthCrawled  NoOfDaysOnline  NoOfHrsOnline  \
# 0         2016           March        March              14              3
#
#    yearsOld  monthsOld
# 0        23         11

# %%
fig, ax = plt.subplots(figsize=(16,6))
sns.countplot("brand", data = df)
ax.set_xticklabels(df.brand.unique(), rotation=90);

# %% [markdown]
# fig, ax = plt.subplots(figsize=(16,6))
# df.brand.value_counts().plot()
# ax.set_xticklabels(df.brand.unique(), rotation=90);

# %% [markdown]
# ### Average price for vehicles based on the type of vehicle as well as on the type of gearbox

# %%
fig, ax = plt.subplots(figsize=(8,10))
sns.set_style("darkgrid")
df.groupby(["vehicleType", "gearbox"]).price.mean().plot.barh();

# %% [markdown]
# ### Average price of vehicle by fuel type as well as on the type of gearbox

# %%
fig, ax = plt.subplots(figsize=(8,10))
sns.set_style("darkgrid")
df.groupby(["fuelType", "gearbox"]).price.mean().plot.barh();

# %% [markdown]
# ### Average price of vehicles by vehicle type and brand (heatmap) (first: groupby method, then: pivot table, finally heatmap)

# %%
xxx = pd.DataFrame(df.groupby(["vehicleType", "brand"]).price.mean())

# %%
xxx
# Out:
#                                price
# vehicleType brand
# Other       alfa_romeo    669.805556
#             audi         1012.599251
#             bmw           896.748086
#             chevrolet    1250.135593
#             chrysler      915.701299
# ...                              ...
# suv         suzuki       5400.337766
#             toyota       8890.557173
#             trabant     14500.000000
#             volkswagen  13946.283675
#             volvo       14081.237918
#
# [333 rows x 1 columns]

# %%
xxx = xxx.pivot_table("price", "brand", "vehicleType")
xxx
# Out:
# vehicleType           Other       andere          bus        cabrio  \
# brand
# alfa_romeo       669.805556   962.500000          NaN   7035.727778
# audi            1012.599251  2685.311828  3485.000000   9655.285628
# bmw              896.748086  1720.388393  4064.000000   8613.779584
# chevrolet       1250.135593  3059.590909  5188.013699  10590.294118
# chrysler         915.701299  2919.714286  2395.083333   4160.719665
# citroen          912.367647  2248.972727  4036.490718   4536.408696
# dacia           1674.875000  3560.000000  8370.729167           NaN
# daewoo           664.204082   993.800000  1262.777778    900.000000
# daihatsu         614.675676  1075.000000  1201.500000   7761.000000
# fiat             807.092511  2639.846154  3372.793827   6315.888676
# ford             693.239709  2142.111111  4714.531100   3884.274671
# honda            857.803109  2417.000000  4551.638554   4152.757576
# hyundai         1030.820755  3435.571429  3751.895833    550.000000
# jaguar           974.875000          NaN          NaN  15076.600000
# jeep             960.210526          NaN  7000.000000   1350.000000
# kia             1012.903614  2435.318182  3347.051852  10000.000000
# saab             2385.863636  2350.000000  3399.250000  2671.038278
# seat             5086.965909  1796.735469  4612.738028  4237.097698
# skoda            3533.000000  2718.592920  5385.649313  4333.090164
# smart            3851.677419  2614.984540  1705.555556  2842.724138
# sonstige_autos  10972.600806  1888.739130  3630.492424  4595.982544
# subaru          10418.625000  1405.099099  2786.565972  4038.678322
# suzuki           3252.500000  2312.453988  1583.359551  3864.965116
# toyota           4894.456790  2836.472006  4519.770270  4170.309218
# trabant          3275.000000  2013.810345  1569.227848  1395.704348
# volkswagen       8014.078218  1626.553215  3902.506211  3743.116228
# volvo            5502.100000  1475.000000  2789.709828  3768.010084
#
# vehicleType              suv
# brand
# alfa_romeo          0.000000
# audi            18644.243902
# bmw             12868.142412
# chevrolet        9613.550505
# chrysler         5888.391304
# citroen         10810.540541
# dacia            9761.972093
# daewoo           1900.000000
# daihatsu         2066.918367
# fiat             8527.000000
# ford            10897.829235
# honda            7795.836364
# hyundai          8354.515487
# jaguar                   NaN
# jeep             9082.630970
# kia              9992.763359
# lada             3788.722689
# lancia                   NaN
# land_rover      10893.121739
# mazda           11683.457895
# mercedes_benz   13059.200687
# mini            18268.115385
# mitsubishi       6944.012019
# nissan           9073.193992
# opel             7451.099099
# peugeot         11945.440000
# porsche         15177.366906
# renault          9279.731183
# rover            7907.142857
# saab            11499.250000
# seat             8711.750000
# skoda           14389.939394
# smart                    NaN
# sonstige_autos  10588.095436
# subaru           4720.031746
# suzuki           5400.337766
# toyota           8890.557173
# trabant         14500.000000
# volkswagen      13946.283675
# volvo           14081.237918

# %%
fig, ax = plt.subplots(figsize=(12,20))
sns.heatmap(xxx, cmap="coolwarm");

# %% [markdown]
# ### Avg price of car by most common 15 years (or in last 15 years)

# %%
df["dateCrawled"] =pd.to_datetime(df.dateCrawled)

# %%
df.dateCrawled.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.set_index('dateCrawled', inplace=True)

# %%
df.head(1)
# Out:
#                            name  seller offerType  price abtest vehicleType  \
# dateCrawled
# 2016-03-24 11:52:17  Golf_3_1.6  privat     Offer    480   test       Other
#
#                      yearOfRegistration  gearbox  powerPS model  kilometer  \
# dateCrawled
# 2016-03-24 11:52:17                1993  manuell        0  golf     150000
#
#                     monthOfRegistration  fuelType       brand  \
# dateCrawled
# 2016-03-24 11:52:17                 Jan  Gasoline  volkswagen
#
#                     notRepairedDamage          dateCreated  postalCode  \
# dateCrawled
# 2016-03-24 11:52:17             Other  2016-03-24 00:00:00       70435
#
#                                 lastSeen  yearOfCreation  yearCrawled  \
# dateCrawled
# 2016-03-24 11:52:17  2016-04-07 03:16:57            2016         2016
#
#                     monthOfCreation monthCrawled  NoOfDaysOnline  \
# dateCrawled
# 2016-03-24 11:52:17           March        March              14
#
#                      NoOfHrsOnline  yearsOld  monthsOld
# dateCrawled
# 2016-03-24 11:52:17              3        23         11

# %%
df.index.year
# Out:
# Int64Index([2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016,
#             ...
#             2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016],
#            dtype='int64', name='dateCrawled', length=313687)

# %%
df.groupby(df.index.year).price.mean()
# Out:
# dateCrawled
# 2016    3902.961863
# Name: price, dtype: float64
