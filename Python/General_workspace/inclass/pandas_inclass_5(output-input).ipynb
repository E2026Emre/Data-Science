# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\acer\\DS\\General_workspace'

# %% [markdown]
# # csv

# %%
df = pd.read_csv("example.csv")

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#                         PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund           Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings          Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen        Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle         Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen            Mr. William Henry\tmale\t35\t0\t0\t373450\t8....
# ...                                                                    ...
# 152\t1\t1\tPears          Mrs. Thomas (Edith Wearne)\tfemale\t22\t1\t0\...
# 153\t0\t3\tMeo            Mr. Alfonzo\tmale\t55.5\t0\t0\tA.5. 11206\t8....
# 154\t0\t3\tvan Billiard   Mr. Austin Blyler\tmale\t40.5\t0\t2\tA/5. 851...
# 155\t0\t3\tOlsen          Mr. Ole Martin\tmale\t\t0\t0\tFa 265302\t7.31...
# 156\t0\t1\tWilliams       Mr. Charles Duane\tmale\t51\t0\t1\tPC 17597\t...
#
# [156 rows x 1 columns]

# %%
# ?pd.read_csv

# %%
pd.read_csv("titanic.csv", sep = "\t")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv("example.csv")

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.drop("d", axis = 1, inplace = True)

# %%
df
# Out:
#     a   b   c
# 0   0   1   2
# 1   4   5   6
# 2   8   9  10
# 3  12  13  14

# %%
df.to_csv("example1.csv", index = False)

# %%
pd.read_csv("example1.csv")
# Out:
#     a   b   c
# 0   0   1   2
# 1   4   5   6
# 2   8   9  10
# 3  12  13  14

# %%
df.to_csv("example2.csv")

# %%
pd.read_csv("example2.csv")
# Out:
#    Unnamed: 0   a   b   c
# 0           0   0   1   2
# 1           1   4   5   6
# 2           2   8   9  10
# 3           3  12  13  14

# %%
pd.read_csv("example2.csv", index_col = 0)
# Out:
#     a   b   c
# 0   0   1   2
# 1   4   5   6
# 2   8   9  10
# 3  12  13  14

# %% [markdown]
# # excel

# %%
df = pd.read_excel("Excel_Sample.xlsx")

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df1 = pd.read_excel("Excel_Sample.xlsx", sheet_name = "Sheet2")

# %%
df1
# Out:
#     a   b    c   d
# 0  11  55  123   3
# 1  22  66  234   7
# 2  33  77  456  11
# 3  44  88  678  15

# %%
df2 = pd.read_excel("ornekx.xlsx")

# %%
df2
# Out:
#         a      b     c
# 0    78.0   12.0   1.0
# 1    78.0   12.0   2.0
# 2    78.0  324.0   3.0
# 3     7.0    2.0   4.0
# 4     NaN   23.0   5.0
# 5     6.0    2.0   NaN
# 6     NaN   11.0   6.0
# 7     7.0   12.0   7.0
# 8    56.0   21.0   7.0
# 9   346.0    NaN   8.0
# 10    5.0    1.0   8.0
# 11  456.0   21.0   8.0
# 12    3.0   12.0  88.0

# %%
df.to_excel("Excel_Sample3.xlsx", sheet_name = "Sheet1", index = False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-39309c120e4b> in <module>
# ----> 1 df.to_excel("Excel_Sample3.xlsx", sheet_name = "Sheet1", index = False)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2021             inf_rep=inf_rep,
#    2022         )
# -> 2023         formatter.write(
#    2024             excel_writer,
#    2025             sheet_name=sheet_name,
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     728             need_save = False
#     729         else:
# ...

# %% [markdown]
# # html

# %%
df4 = pd.read_html("http://www.fdic.gov/bank/individual/failed/banklist.html")

# %%
df4
# Out:
# [                             Bank Name           City  ST   CERT  \
#  0                 The First State Bank  Barboursville  WV  14361
#  1                   Ericson State Bank        Ericson  NE  18265
#  2     City National Bank of New Jersey         Newark  NJ  21111
#  3                        Resolute Bank         Maumee  OH  58317
#  4                Louisa Community Bank         Louisa  KY  58112
#  ..                                 ...            ...  ..    ...
#  556                 Superior Bank, FSB       Hinsdale  IL  32646
#  557                Malta National Bank          Malta  OH   6629
#  558    First Alliance Bank & Trust Co.     Manchester  NH  34264
#  559  National State Bank of Metropolis     Metropolis  IL   3815
#  560                   Bank of Honolulu       Honolulu  HI  21029
#
#                     Acquiring Institution       Closing Date
#  0                         MVB Bank, Inc.      April 3, 2020
# ...

# %%
df4[0]
# Out:
#                              Bank Name           City  ST   CERT  \
# 0                 The First State Bank  Barboursville  WV  14361
# 1                   Ericson State Bank        Ericson  NE  18265
# 2     City National Bank of New Jersey         Newark  NJ  21111
# 3                        Resolute Bank         Maumee  OH  58317
# 4                Louisa Community Bank         Louisa  KY  58112
# ..                                 ...            ...  ..    ...
# 556                 Superior Bank, FSB       Hinsdale  IL  32646
# 557                Malta National Bank          Malta  OH   6629
# 558    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 559  National State Bank of Metropolis     Metropolis  IL   3815
# 560                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date
# 0                         MVB Bank, Inc.      April 3, 2020
# 1             Farmers and Merchants Bank  February 14, 2020
# ...

# %%
df5 = pd.read_html("https://en.wikipedia.org/wiki/Pythonidae")

# %%
df5[0]
# Out:
#     0                                                  1
# 0 NaN  This article's lead section does not adequatel...
