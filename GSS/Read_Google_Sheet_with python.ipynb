# %%
import pandas as pd

# %%
#Replace "edit" with "export?format=csv&" in file url to read from a Google Sheets file.
# Be sure that the sharing options is "Anyone with the link".

file_url="https://docs.google.com/spreadsheets/d/1vXPjsBfZsO3Bn34VYS-Idkd8iqD1aMNCXxFGrmjyrVs/export?format=csv&?usp=sharing"

df=pd.read_csv(file_url, index_col="#")

# %%
df.head()
# Out:
#   listing_date sale_or_rent re_type  location    rooms area age  \
# #
# 1    10/3/2020      Satılık   Daire   Maltepe    2 + 1   90   4
# 2    10/5/2020      Satılık   Daire   Maltepe    3 + 1  100   3
# 3    8/17/2020      Satılık   Plaza  Ataşehir  6 Bölüm  800  15
# 4    10/9/2020      Satılık   Daire   Maltepe    2 + 1   90  25
# 5    10/9/2020      Satılık   Daire   Maltepe    2 + 1   90   6
#
#            floor       price
# #
# 1     Bahçe Katı    ₺650,000
# 2         4. Kat    ₺780,000
# 3  No floor data  ₺3,300,000
# 4     Giriş Katı    ₺450,000
# 5     Bahçe Katı    ₺465,000
